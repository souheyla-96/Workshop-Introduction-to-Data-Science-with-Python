# %%
import pandas as pd
import numpy as np

# Replace with the actual dataset path from Padoc
df = pd.read_csv("C:/Users/FAROUK/Downloads/archive/spot.csv")

# Inspect the first few rows
print(df.head())
# Out:
#                  track_id                           track_name  track_number  \
# 0  6pymOcrCnMuCWdgGVTvUgP                                    3            57
# 1  2lWc1iJlz2NVcStV5fbtPG                               Clouds             1
# 2  1msEuwSBneBKpVCZQcFTsU  Forever & Always (Taylor’s Version)            11
# 3  7bcy34fBT2ap1L4bfPsl9q            I Didn't Change My Number             2
# 4  0GLfodYacy3BJE7AI3A8en                             Man Down             7
#
#    track_popularity  track_duration_ms  explicit     artist_name  \
# 0                61             213173     False  Britney Spears
# 1                67             158760     False           BUNT.
# 2                63             225328     False    Taylor Swift
# 3                72             158463      True   Billie Eilish
# 4                57             267013     False         Rihanna
#
#    artist_popularity  artist_followers      artist_genres  \
# 0               80.0        17755451.0            ['pop']
# 1               69.0          293734.0  ['stutter house']
# 2              100.0       145396321.0                 []
# 3               90.0       118692183.0                 []
# 4               90.0        68997177.0                 []
#
#                  album_id                   album_name album_release_date  \
# 0  325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1  2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2  4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3  0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4  5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
#
#    album_total_tracks   album_type
# 0                  58  compilation
# 1                   1       single
# 2                  26        album
# 3                  16        album
# 4                  13        album

# %%
df[['track_id', 'track_name']]
# Out:
#                     track_id                              track_name
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
# [8778 rows x 2 columns]

# %%
print(df.columns)  #same with print
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'track_duration_ms', 'explicit', 'artist_name', 'artist_popularity',
#        'artist_followers', 'artist_genres', 'album_id', 'album_name',
#        'album_release_date', 'album_total_tracks', 'album_type'],
#       dtype='object')

# %%
df.sample(3)   # 3 lignes aléatoires
# Out:
#                     track_id      track_name  track_number  track_popularity  \
# 4912  0837Am3wsBxCmfxo1DiFmz  Hollywood Bowl            14                45
# 372   4tViDtaHuSLnh7HVJTrKhs   Power Over Me             3                65
# 6121  6wOmmoM5nyS6mOyzo9wDjC    Buyer Beware            14                51
#
#       track_duration_ms  explicit     artist_name  artist_popularity  \
# 4912             253240     False       Rob Grant               39.0
# 372              206960     False  Dermot Kennedy               68.0
# 6121             173481      True     Post Malone               86.0
#
#       artist_followers artist_genres                album_id    album_name  \
# 4912           49536.0            []  7kwav2MO9gEBS55o0Ui3n9   Lost At Sea
# 372          1668880.0            []  7jGNAMzrW5HMXdxl9XyBMG  Without Fear
# 6121        47720209.0            []  6r1lh7fHMB499vGKtIyJLy        AUSTIN
#
#      album_release_date  album_total_tracks album_type
# 4912         2023-06-09                  14      album
# 372          2019-10-04                  13      album
# 6121         2023-07-28                  17      album

# %%
df.tail() # last 5 lines
# Out:
#                     track_id                              track_name  \
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 8773             1                65             209698     False
# 8774             4                 2             113143     False
# 8775             4                81             218880      True
# 8776             1                84             203600     False
# 8777             4                33             261385      True
#
#        artist_name  artist_popularity  artist_followers       artist_genres  \
# 8773  Paris Paloma               66.0          786890.0                  []
# 8774         Zelda                8.0            3263.0                  []
# 8775    The Weeknd               94.0       113039308.0                  []
# 8776           bôa               68.0         1188508.0                  []
# 8777        Eminem               88.0       104584370.0  ['rap', 'hip hop']
#
#                     album_id                album_name album_release_date  \
# 8773  48ssTnnFOCIP17sRaFNqu1                the fruits         2022-04-29
# 8774  0JJAfVZtn3EvZnXSQrpLSh       The Legend of Zelda         2023-08-19
# 8775  2ODvWsOgouMbaA5xf0RkJe                   Starboy         2016-11-25
# 8776  7sGYAV0xv7ZfAMzIpMl8m1                  Twilight         2001-03-21
# 8777  3vOgbDjgsZBAPwV2M3bNOj  The Marshall Mathers LP2         2013-11-05
#
#       album_total_tracks album_type
# 8773                   1     single
# 8774                   7      album
# 8775                  18      album
# 8776                  14      album
# 8777                  16      album

# %%
df.dtypes
# Out:
# track_id               object
# track_name             object
# track_number            int64
# track_popularity        int64
# track_duration_ms       int64
# explicit                 bool
# artist_name            object
# artist_popularity     float64
# artist_followers      float64
# artist_genres          object
# album_id               object
# album_name             object
# album_release_date     object
# album_total_tracks      int64
# album_type             object
# dtype: object

# %%
df.info() # full summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8778 entries, 0 to 8777
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8778 non-null   object
#  1   track_name          8776 non-null   object
#  2   track_number        8778 non-null   int64
#  3   track_popularity    8778 non-null   int64
#  4   track_duration_ms   8778 non-null   int64
#  5   explicit            8778 non-null   bool
#  6   artist_name         8774 non-null   object
#  7   artist_popularity   8774 non-null   float64
#  8   artist_followers    8774 non-null   float64
#  9   artist_genres       8774 non-null   object
#  10  album_id            8778 non-null   object
#  11  album_name          8776 non-null   object
#  12  album_release_date  8778 non-null   object
#  13  album_total_tracks  8778 non-null   int64
#  14  album_type          8778 non-null   object
# dtypes: bool(1), float64(2), int64(4), object(8)
# memory usage: 968.8+ KB

# %%
df.describe()                       # numerical statistical summary
# Out:
#        track_number  track_popularity  track_duration_ms  artist_popularity  \
# count   8778.000000       8778.000000        8778.000000        8774.000000
# mean       5.749487         52.232855      210157.791866          69.954981
# std        6.017938         24.075221       63326.841454          19.532783
# min        1.000000          0.000000           0.000000           0.000000
# 25%        1.000000         39.000000      173921.250000          60.000000
# 50%        4.000000         58.000000      207276.000000          74.000000
# 75%        9.000000         71.000000      239693.250000          84.000000
# max      102.000000        100.000000      811077.000000         100.000000
#
#        artist_followers  album_total_tracks
# count      8.774000e+03         8778.000000
# mean       2.435487e+07           13.779790
# std        3.813769e+07           11.797943
# min        0.000000e+00            1.000000
# 25%        5.152768e+05            6.000000
# 50%        6.272266e+06           13.000000
# 75%        3.055055e+07           17.000000
# max        1.455421e+08          181.000000

# %%
df.describe().round(2)   #Round all numerical statistics in the summary to 2 decimal places for better readability
# Out:
#        track_number  track_popularity  track_duration_ms  artist_popularity  \
# count       8778.00           8778.00            8778.00            8774.00
# mean           5.75             52.23          210157.79              69.95
# std            6.02             24.08           63326.84              19.53
# min            1.00              0.00               0.00               0.00
# 25%            1.00             39.00          173921.25              60.00
# 50%            4.00             58.00          207276.00              74.00
# 75%            9.00             71.00          239693.25              84.00
# max          102.00            100.00          811077.00             100.00
#
#        artist_followers  album_total_tracks
# count      8.774000e+03             8778.00
# mean       2.435487e+07               13.78
# std        3.813769e+07               11.80
# min        0.000000e+00                1.00
# 25%        5.152768e+05                6.00
# 50%        6.272266e+06               13.00
# 75%        3.055055e+07               17.00
# max        1.455421e+08              181.00

# %%
df['track_number'].value_counts()       # frequency of values
# Out:
# track_number
# 1      2755
# 2       838
# 3       713
# 4       583
# 5       501
# 6       436
# 7       368
# 9       346
# 8       342
# 10      315
# 11      286
# 12      234
# 13      206
# 14      171
# 16      125
# 15      125
# 17       87
# 18       62
# 19       46
# 20       43
# 21       28
# 22       28
# 24       19
# 23       16
# 25       16
# 26       12
# 28        8
# 30        7
# 27        5
# 35        5
# 38        5
# 40        4
# 32        4
# 29        4
# 31        3
# 37        3
# 45        3
# 44        3
# 47        2
# 36        2
# 34        2
# 46        2
# 43        2
# 33        2
# 41        2
# 42        1
# 39        1
# 52        1
# 54        1
# 57        1
# 102       1
# 66        1
# 49        1
# 70        1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns',None) # display all columns\n
print(df)
# Out:
#                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 0               57                61             213173     False
# 1                1                67             158760     False
# 2               11                63             225328     False
# 3                2                72             158463      True
# 4                7                57             267013     False
# ...            ...               ...                ...       ...
# 8773             1                65             209698     False
# 8774             4                 2             113143     False
# 8775             4                81             218880      True
# 8776             1                84             203600     False
# 8777             4                33             261385      True
#
#          artist_name  artist_popularity  artist_followers       artist_genres  \
# 0     Britney Spears               80.0        17755451.0             ['pop']
# 1              BUNT.               69.0          293734.0   ['stutter house']
# 2       Taylor Swift              100.0       145396321.0                  []
# 3      Billie Eilish               90.0       118692183.0                  []
# 4            Rihanna               90.0        68997177.0                  []
# ...              ...                ...               ...                 ...
# 8773    Paris Paloma               66.0          786890.0                  []
# 8774           Zelda                8.0            3263.0                  []
# 8775      The Weeknd               94.0       113039308.0                  []
# 8776             bôa               68.0         1188508.0                  []
# 8777          Eminem               88.0       104584370.0  ['rap', 'hip hop']
#
#                     album_id                   album_name album_release_date  \
# 0     325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1     2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2     4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3     0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4     5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
# ...                      ...                          ...                ...
# 8773  48ssTnnFOCIP17sRaFNqu1                   the fruits         2022-04-29
# 8774  0JJAfVZtn3EvZnXSQrpLSh          The Legend of Zelda         2023-08-19
# 8775  2ODvWsOgouMbaA5xf0RkJe                      Starboy         2016-11-25
# 8776  7sGYAV0xv7ZfAMzIpMl8m1                     Twilight         2001-03-21
# 8777  3vOgbDjgsZBAPwV2M3bNOj     The Marshall Mathers LP2         2013-11-05
#
#       album_total_tracks   album_type
# 0                     58  compilation
# 1                      1       single
# 2                     26        album
# 3                     16        album
# 4                     13        album
# ...                  ...          ...
# 8773                   1       single
# 8774                   7        album
# 8775                  18        album
# 8776                  14        album
# 8777                  16        album
#
# [8778 rows x 15 columns]

# %%
pd.set_option('display.precision',2) # number of decimal places
print(df)
# Out:
#                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 0               57                61             213173     False
# 1                1                67             158760     False
# 2               11                63             225328     False
# 3                2                72             158463      True
# 4                7                57             267013     False
# ...            ...               ...                ...       ...
# 8773             1                65             209698     False
# 8774             4                 2             113143     False
# 8775             4                81             218880      True
# 8776             1                84             203600     False
# 8777             4                33             261385      True
#
#          artist_name  artist_popularity  artist_followers       artist_genres  \
# 0     Britney Spears               80.0          1.78e+07             ['pop']
# 1              BUNT.               69.0          2.94e+05   ['stutter house']
# 2       Taylor Swift              100.0          1.45e+08                  []
# 3      Billie Eilish               90.0          1.19e+08                  []
# 4            Rihanna               90.0          6.90e+07                  []
# ...              ...                ...               ...                 ...
# 8773    Paris Paloma               66.0          7.87e+05                  []
# 8774           Zelda                8.0          3.26e+03                  []
# 8775      The Weeknd               94.0          1.13e+08                  []
# 8776             bôa               68.0          1.19e+06                  []
# 8777          Eminem               88.0          1.05e+08  ['rap', 'hip hop']
#
#                     album_id                   album_name album_release_date  \
# 0     325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1     2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2     4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3     0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4     5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
# ...                      ...                          ...                ...
# 8773  48ssTnnFOCIP17sRaFNqu1                   the fruits         2022-04-29
# 8774  0JJAfVZtn3EvZnXSQrpLSh          The Legend of Zelda         2023-08-19
# 8775  2ODvWsOgouMbaA5xf0RkJe                      Starboy         2016-11-25
# 8776  7sGYAV0xv7ZfAMzIpMl8m1                     Twilight         2001-03-21
# 8777  3vOgbDjgsZBAPwV2M3bNOj     The Marshall Mathers LP2         2013-11-05
#
#       album_total_tracks   album_type
# 0                     58  compilation
# 1                      1       single
# 2                     26        album
# 3                     16        album
# 4                     13        album
# ...                  ...          ...
# 8773                   1       single
# 8774                   7        album
# 8775                  18        album
# 8776                  14        album
# 8777                  16        album
#
# [8778 rows x 15 columns]

# %%
df ['album_type'] # single column
# Out:
# 0       compilation
# 1            single
# 2             album
# 3             album
# 4             album
#            ...
# 8773         single
# 8774          album
# 8775          album
# 8776          album
# 8777          album
# Name: album_type, Length: 8778, dtype: object

# %%
df [['track_name' , 'album_type']] # multiple columns
# Out:
#                                   track_name   album_type
# 0                                          3  compilation
# 1                                     Clouds       single
# 2        Forever & Always (Taylor’s Version)        album
# 3                  I Didn't Change My Number        album
# 4                                   Man Down        album
# ...                                      ...          ...
# 8773                              the fruits       single
# 8774  Dark World Theme (The Legend of Zelda)        album
# 8775                                Reminder        album
# 8776                                   Duvet        album
# 8777                          So Much Better        album
#
# [8778 rows x 2 columns]

# %%
df.iloc[0] # first line
# Out:
# track_id              6pymOcrCnMuCWdgGVTvUgP
# track_name                                 3
# track_number                              57
# track_popularity                          61
# track_duration_ms                     213173
# explicit                               False
# artist_name                   Britney Spears
# artist_popularity                       80.0
# artist_followers                  17755451.0
# artist_genres                        ['pop']
# album_id              325wcm5wMnlfjmKZ8PXIIn
# album_name            The Singles Collection
# album_release_date                2009-11-09
# album_total_tracks                        58
# album_type                       compilation
# Name: 0, dtype: object

# %%
df.iloc[0:5] # lines 0 to 4\n
# Out:
#                  track_id                           track_name  track_number  \
# 0  6pymOcrCnMuCWdgGVTvUgP                                    3            57
# 1  2lWc1iJlz2NVcStV5fbtPG                               Clouds             1
# 2  1msEuwSBneBKpVCZQcFTsU  Forever & Always (Taylor’s Version)            11
# 3  7bcy34fBT2ap1L4bfPsl9q            I Didn't Change My Number             2
# 4  0GLfodYacy3BJE7AI3A8en                             Man Down             7
#
#    track_popularity  track_duration_ms  explicit     artist_name  \
# 0                61             213173     False  Britney Spears
# 1                67             158760     False           BUNT.
# 2                63             225328     False    Taylor Swift
# 3                72             158463      True   Billie Eilish
# 4                57             267013     False         Rihanna
#
#    artist_popularity  artist_followers      artist_genres  \
# 0               80.0          1.78e+07            ['pop']
# 1               69.0          2.94e+05  ['stutter house']
# 2              100.0          1.45e+08                 []
# 3               90.0          1.19e+08                 []
# 4               90.0          6.90e+07                 []
#
#                  album_id                   album_name album_release_date  \
# 0  325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1  2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2  4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3  0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4  5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
#
#    album_total_tracks   album_type
# 0                  58  compilation
# 1                   1       single
# 2                  26        album
# 3                  16        album
# 4                  13        album

# %%
df.loc [df['track_duration_ms'] >220000] # conditional filtering
# Out:
#                     track_id                           track_name  \
# 2     1msEuwSBneBKpVCZQcFTsU  Forever & Always (Taylor’s Version)
# 4     0GLfodYacy3BJE7AI3A8en                             Man Down
# 5     7H0ya83CMmgFcOhw0UB6ow                           Space Song
# 8     0N5zjRnf8AreOm95iSBXF4           Even My Dad Does Sometimes
# 10    5JLv62qFIS1DR3zGEcApRt                           Wide Awake
# ...                      ...                                  ...
# 8757  27PTd8bvvSpk9qXtNwxbe7                      Leave Me Lonely
# 8762  3GYlZ7tbxLOxe6ewMNVTkw                                   TV
# 8767  1mXuMM6zjPgjL4asbBsgnt                             Firework
# 8772  2d8JP84HNLKhmd6IYOoupQ                           Trap Queen
# 8777  7KZJnMtwu2s80jO5Frthap                       So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 2               11                63             225328     False
# 4                7                57             267013     False
# 5                3                77             320466     False
# 8               15                50             228533     False
# 10              15                75             220946     False
# ...            ...               ...                ...       ...
# 8757             8                54             229680     False
# 8762             1                83             281380     False
# 8767             4                69             227893     False
# 8772             1                77             222093      True
# 8777             4                33             261385      True
#
#         artist_name  artist_popularity  artist_followers       artist_genres  \
# 2      Taylor Swift              100.0          1.45e+08                  []
# 4           Rihanna               90.0          6.90e+07                  []
# 5       Beach House               72.0          2.80e+06       ['dream pop']
# 8        Ed Sheeran               88.0          1.23e+08        ['soft pop']
# 10       Katy Perry               83.0          3.84e+07             ['pop']
# ...             ...                ...               ...                 ...
# 8757  Ariana Grande               90.0          1.07e+08             ['pop']
# 8762  Billie Eilish               90.0          1.19e+08                  []
# 8767     Katy Perry               83.0          3.84e+07             ['pop']
# 8772      Fetty Wap               70.0          5.12e+06                  []
# 8777         Eminem               88.0          1.05e+08  ['rap', 'hip hop']
#
#                     album_id                              album_name  \
# 2     4hDok0OAJd57SGIT8xuWJH             Fearless (Taylor's Version)
# 4     5QG3tjE5L9F6O2vCAPph38                                    Loud
# 5     194CqC2Zi0kUFEPWedb3qr                       Depression Cherry
# 8     1xn54DMo2qIqBuMqHtUsFd                      x (Deluxe Edition)
# 10    5BvgP623rtvlc0HDcpzquz  Teenage Dream: The Complete Confection
# ...                      ...                                     ...
# 8757  1QRP5lutJodPixU2EWfnD7                         Dangerous Woman
# 8762  1YPWxMpQEC8kcOuefgXbhj                            Guitar Songs
# 8767  06SY6Ke6mXzZHhURLVU57R                           Teenage Dream
# 8772  2gKQvajkEEaDtkqJ8FJ4uw                      Fetty Wap (Deluxe)
# 8777  3vOgbDjgsZBAPwV2M3bNOj                The Marshall Mathers LP2
#
#      album_release_date  album_total_tracks album_type
# 2            2021-04-09                  26      album
# 4            2010-01-01                  13      album
# 5            2015-08-28                   9      album
# 8            2014-06-21                  16      album
# 10           2012-03-12                  19      album
# ...                 ...                 ...        ...
# 8757         2016-04-01                  15      album
# 8762         2022-07-21                   2     single
# 8767         2010-08-24                  17      album
# 8772         2015-09-25                  20      album
# 8777         2013-11-05                  16      album
#
# [3466 rows x 15 columns]

# %%
df ['totale album duration'] = (df['track_duration_ms']) * (df['track_number'])

# %%
pd.reset_option('display.max_columns') # reset display option in default model
print(df)
# Out:
#                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 0               57                61             213173     False
# 1                1                67             158760     False
# 2               11                63             225328     False
# 3                2                72             158463      True
# 4                7                57             267013     False
# ...            ...               ...                ...       ...
# 8773             1                65             209698     False
# 8774             4                 2             113143     False
# 8775             4                81             218880      True
# 8776             1                84             203600     False
# 8777             4                33             261385      True
#
#          artist_name  artist_popularity  artist_followers       artist_genres  \
# 0     Britney Spears               80.0          1.78e+07             ['pop']
# 1              BUNT.               69.0          2.94e+05   ['stutter house']
# 2       Taylor Swift              100.0          1.45e+08                  []
# 3      Billie Eilish               90.0          1.19e+08                  []
# 4            Rihanna               90.0          6.90e+07                  []
# ...              ...                ...               ...                 ...
# 8773    Paris Paloma               66.0          7.87e+05                  []
# 8774           Zelda                8.0          3.26e+03                  []
# 8775      The Weeknd               94.0          1.13e+08                  []
# 8776             bôa               68.0          1.19e+06                  []
# 8777          Eminem               88.0          1.05e+08  ['rap', 'hip hop']
#
#                     album_id                   album_name album_release_date  \
# 0     325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1     2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2     4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3     0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4     5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
# ...                      ...                          ...                ...
# 8773  48ssTnnFOCIP17sRaFNqu1                   the fruits         2022-04-29
# 8774  0JJAfVZtn3EvZnXSQrpLSh          The Legend of Zelda         2023-08-19
# 8775  2ODvWsOgouMbaA5xf0RkJe                      Starboy         2016-11-25
# 8776  7sGYAV0xv7ZfAMzIpMl8m1                     Twilight         2001-03-21
# 8777  3vOgbDjgsZBAPwV2M3bNOj     The Marshall Mathers LP2         2013-11-05
#
#       album_total_tracks   album_type  totale album duration
# 0                     58  compilation               12150861
# 1                      1       single                 158760
# 2                     26        album                2478608
# 3                     16        album                 316926
# 4                     13        album                1869091
# ...                  ...          ...                    ...
# 8773                   1       single                 209698
# 8774                   7        album                 452572
# 8775                  18        album                 875520
# 8776                  14        album                 203600
# 8777                  16        album                1045540
#
# [8778 rows x 16 columns]

# %%
df.drop ('totale album duration' , axis= 1 , inplace = True) 
        # removes the column named 'mean' from the DataFrame df by specifying \n,
        # axis=1 to indicate a column operation, and inplace=True to apply the change \n,
        # directly without reassigning the DataFrame.\n,
print(df)
# Out:
#                     track_id                              track_name  \
# 0     6pymOcrCnMuCWdgGVTvUgP                                       3
# 1     2lWc1iJlz2NVcStV5fbtPG                                  Clouds
# 2     1msEuwSBneBKpVCZQcFTsU     Forever & Always (Taylor’s Version)
# 3     7bcy34fBT2ap1L4bfPsl9q               I Didn't Change My Number
# 4     0GLfodYacy3BJE7AI3A8en                                Man Down
# ...                      ...                                     ...
# 8773  58VTP6KnZs12PcAj5rMJ4W                              the fruits
# 8774  2dRfUOeTVpr4V4PmmqGkpm  Dark World Theme (The Legend of Zelda)
# 8775  37F0uwRSrdzkBiuj0D5UHI                                Reminder
# 8776  42qNWdLKCI41S4uzfamhFM                                   Duvet
# 8777  7KZJnMtwu2s80jO5Frthap                          So Much Better
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 0               57                61             213173     False
# 1                1                67             158760     False
# 2               11                63             225328     False
# 3                2                72             158463      True
# 4                7                57             267013     False
# ...            ...               ...                ...       ...
# 8773             1                65             209698     False
# 8774             4                 2             113143     False
# 8775             4                81             218880      True
# 8776             1                84             203600     False
# 8777             4                33             261385      True
#
#          artist_name  artist_popularity  artist_followers       artist_genres  \
# 0     Britney Spears               80.0          1.78e+07             ['pop']
# 1              BUNT.               69.0          2.94e+05   ['stutter house']
# 2       Taylor Swift              100.0          1.45e+08                  []
# 3      Billie Eilish               90.0          1.19e+08                  []
# 4            Rihanna               90.0          6.90e+07                  []
# ...              ...                ...               ...                 ...
# 8773    Paris Paloma               66.0          7.87e+05                  []
# 8774           Zelda                8.0          3.26e+03                  []
# 8775      The Weeknd               94.0          1.13e+08                  []
# 8776             bôa               68.0          1.19e+06                  []
# 8777          Eminem               88.0          1.05e+08  ['rap', 'hip hop']
#
#                     album_id                   album_name album_release_date  \
# 0     325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1     2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2     4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3     0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4     5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
# ...                      ...                          ...                ...
# 8773  48ssTnnFOCIP17sRaFNqu1                   the fruits         2022-04-29
# 8774  0JJAfVZtn3EvZnXSQrpLSh          The Legend of Zelda         2023-08-19
# 8775  2ODvWsOgouMbaA5xf0RkJe                      Starboy         2016-11-25
# 8776  7sGYAV0xv7ZfAMzIpMl8m1                     Twilight         2001-03-21
# 8777  3vOgbDjgsZBAPwV2M3bNOj     The Marshall Mathers LP2         2013-11-05
#
#       album_total_tracks   album_type
# 0                     58  compilation
# 1                      1       single
# 2                     26        album
# 3                     16        album
# 4                     13        album
# ...                  ...          ...
# 8773                   1       single
# 8774                   7        album
# 8775                  18        album
# 8776                  14        album
# 8777                  16        album
#
# [8778 rows x 15 columns]

# %%
df[df['album_total_tracks'] == df['album_total_tracks'].min()] # Display the row  with the minimum volume
# Out:
#                     track_id                                   track_name  \
# 1     2lWc1iJlz2NVcStV5fbtPG                                       Clouds
# 9     0qUcpOOna3kkrwfqky85e1  Eyes Blue Like The Atlantic (feat. Subvrbs)
# 11    3LtpKP5abr2qqjunvjlX5i                                         Doja
# 13    779mhz1mAry946r91qzR1r                                  Cheerleader
# 14    2i2gDpKKWjvnRTOZRhaPh2                                    Moonlight
# ...                      ...                                          ...
# 8745  6t62npoUwUGjrwIawdgwA5                              Goodbye For Now
# 8749  0IKK48xF4eEdfofyaeKWWO                                   PILLOWTALK
# 8753  5vRP728TajdjftioyNLqi4                                    Love Mess
# 8769  4y4spB9m0Q6026KfkAvy9Q                   Lonely (with benny blanco)
# 8773  58VTP6KnZs12PcAj5rMJ4W                                   the fruits
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 1                1                67             158760     False
# 9                1                63             154599     False
# 11               1                77              97392      True
# 13               1                45             237567     False
# 14               1                74             187557     False
# ...            ...               ...                ...       ...
# 8745             1                33             210130     False
# 8749             1                63             203686      True
# 8753             1                18             218887     False
# 8769             1                66             149297      True
# 8773             1                65             209698     False
#
#           artist_name  artist_popularity  artist_followers  \
# 1               BUNT.               69.0          2.94e+05
# 9          Sista Prod               48.0          6.82e+04
# 11        Central Cee               79.0          9.67e+06
# 13    Porter Robinson               59.0          1.22e+06
# 14         Kali Uchis               83.0          9.47e+06
# ...               ...                ...               ...
# 8745       Olivia Cox               18.0          1.26e+03
# 8749             ZAYN               77.0          2.41e+07
# 8753           shotty               11.0          3.25e+02
# 8769    Justin Bieber               91.0          8.51e+07
# 8773     Paris Paloma               66.0          7.87e+05
#
#                                    artist_genres                album_id  \
# 1                              ['stutter house']  2ArRQNLxf9t0O0gvmG5Vsj
# 9                                             []  5UYjxc4HIYeesKS0WJlhEI
# 11    ['uk drill', 'drill', 'uk grime', 'grime']  6oECjagksATHu2UaclXrq1
# 13                         ['edm', 'electronic']  0KdbNiljxzEMCwkVJS0wzI
# 14                                            []  1y8Yw0NDcP2qxbZufIXt7u
# ...                                          ...                     ...
# 8745                                  ['hipdut']  5IewtRLurwyZX1ymMd423l
# 8749                                          []  6BUAjgcgWhtTgRXVqCwF4u
# 8753                                          []  2iGHeA60F6JdpC11mRaOKY
# 8769                                          []  3P5WIUJO0Ots1lQx09TOxk
# 8773                                          []  48ssTnnFOCIP17sRaFNqu1
#
#                                        album_name album_release_date  \
# 1                                          Clouds         2023-01-13
# 9     Eyes Blue Like The Atlantic (feat. Subvrbs)         2020-07-20
# 11                                           Doja         2022-07-21
# 13                                    Cheerleader         2024-03-20
# 14                                      Moonlight         2023-02-24
# ...                                           ...                ...
# 8745                              Goodbye For Now         2025-10-10
# 8749                                   PILLOWTALK         2016-01-29
# 8753                                    Love Mess         2025-03-28
# 8769                   Lonely (with benny blanco)         2020-10-16
# 8773                                   the fruits         2022-04-29
#
#       album_total_tracks album_type
# 1                      1     single
# 9                      1     single
# 11                     1     single
# 13                     1     single
# 14                     1     single
# ...                  ...        ...
# 8745                   1     single
# 8749                   1     single
# 8753                   1     single
# 8769                   1     single
# 8773                   1     single
#
# [1649 rows x 15 columns]

# %%
df.sort_values (by = 'album_total_tracks' , ascending = False) #sorting values
# Out:
#                     track_id                              track_name  \
# 511   1116IjCqwjydbV6V0twTEQ           The Thunder-Fire Dragon Roars
# 4212  5KqgCoUfSSqANtyVoHv6Ml                    Stay A Little Longer
# 6797  22IKKMdS3YT11q0If6nHoD                                Don't It
# 6155  1FPSkRkDlthbAceSIIWc4C  Welcome Home (Sanitarium) - Remastered
# 3674  1oQDxrvz8PAxAAs0Sl1dcX          I Don't Want This Night To End
# ...                      ...                                     ...
# 3573  7Hbou0N0vEhKgEVP24LfIR     I Really Want To Stay at Your House
# 7169  47mNWUCgJoXqVWb3UZytVa                              To Be Free
# 5450  7iVHRWUwWqrGwjotzYewWe                                 flannel
# 7167  5UVuNesgreHU8rfS3Rc00q                                   Altyn
# 2964  3A7qX2QjDlPnazUsRk5y0M                2U (feat. Justin Bieber)
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 511              1                28             126200     False
# 4212             5                36             335480     False
# 6797            38                37             189000     False
# 6155             4                59             387146     False
# 3674           102                44             219973     False
# ...            ...               ...                ...       ...
# 3573             1                41             186250     False
# 7169             1                61             255155     False
# 5450             1                 0             117413      True
# 7167             1                 0             101958      True
# 2964             1                63             194896     False
#
#              artist_name  artist_popularity  artist_followers  \
# 511   Yasuharu Takanashi               58.0          1.12e+05
# 4212    Brothers Osborne               58.0          1.27e+06
# 6797    Billy Currington               65.0          2.76e+06
# 6155           Metallica               81.0          3.22e+07
# 3674          Luke Bryan               74.0          9.41e+06
# ...                  ...                ...               ...
# 3573                Cour               46.0          6.58e+03
# 7169           Sam Smith               81.0          2.63e+07
# 5450            Lil Peep               82.0          1.57e+07
# 7167              framed               42.0          8.43e+04
# 2964        David Guetta               87.0          2.71e+07
#
#                                           artist_genres  \
# 511                             ['anime', 'soundtrack']
# 4212                        ['country', 'country rock']
# 6797                    ['country', 'acoustic country']
# 6155  ['metal', 'thrash metal', 'rock', 'heavy metal...
# 3674                    ['country', 'acoustic country']
# ...                                                 ...
# 3573                                     ['slap house']
# 7169                                       ['soft pop']
# 5450                           ['emo rap', 'cloud rap']
# 7167                                                 []
# 2964                                            ['edm']
#
#                     album_id                                       album_name  \
# 511   3ksMU0uVKKlBDqPjmaot0v         FAIRY TAIL SOUNDTRACK ARCHIVES 2009-2013
# 4212  6hS50PV0K45RAjVnoJ4f2g            Best Country Of The Decade: 2010-2019
# 6797  6hS50PV0K45RAjVnoJ4f2g            Best Country Of The Decade: 2010-2019
# 6155  5rFZcoCvmCaJ1gxTMU4JTm  Master Of Puppets (Deluxe Box Set / Remastered)
# 3674  4a4OT9y3kV3S36HHf5Zj9q            Best Country Of The Decade: 2011-2020
# ...                      ...                                              ...
# 3573  7FWbPLrsboCMWRnwxbkh2d              I Really Want To Stay at Your House
# 7169  4CbMJCzMlzyEByCi84kllb                                       To Be Free
# 5450  7lNwTREIbdqfWAhTbFVOE7                                          flannel
# 7167  6C6Rv6NFyonYWOv3X0LdGF                                            Altyn
# 2964  1PZviVfBJJxNw5EtAwzdUu                         2U (feat. Justin Bieber)
#
#      album_release_date  album_total_tracks   album_type
# 511          2022-03-16                 181        album
# 4212         2019-12-20                 144  compilation
# 6797         2019-12-20                 144  compilation
# 6155         1986-03-03                 137        album
# 3674         2020-12-15                 136  compilation
# ...                 ...                 ...          ...
# 3573         2024-07-09                   1       single
# 7169         2025-07-24                   1       single
# 5450         2022-11-04                   1       single
# 7167         2022-08-09                   1       single
# 2964         2017-06-09                   1       single
#
# [8778 rows x 15 columns]

# %%
 #Rename 'Unnamed: 0' to 'index'
df.rename(columns={'Unnamed: 0': 'index'}, inplace=True)
# Display the first rows to confirm
df.head() # first 5 lines
# Out:
#                  track_id                           track_name  track_number  \
# 0  6pymOcrCnMuCWdgGVTvUgP                                    3            57
# 1  2lWc1iJlz2NVcStV5fbtPG                               Clouds             1
# 2  1msEuwSBneBKpVCZQcFTsU  Forever & Always (Taylor’s Version)            11
# 3  7bcy34fBT2ap1L4bfPsl9q            I Didn't Change My Number             2
# 4  0GLfodYacy3BJE7AI3A8en                             Man Down             7
#
#    track_popularity  track_duration_ms  explicit     artist_name  \
# 0                61             213173     False  Britney Spears
# 1                67             158760     False           BUNT.
# 2                63             225328     False    Taylor Swift
# 3                72             158463      True   Billie Eilish
# 4                57             267013     False         Rihanna
#
#    artist_popularity  artist_followers      artist_genres  \
# 0               80.0          1.78e+07            ['pop']
# 1               69.0          2.94e+05  ['stutter house']
# 2              100.0          1.45e+08                 []
# 3               90.0          1.19e+08                 []
# 4               90.0          6.90e+07                 []
#
#                  album_id                   album_name album_release_date  \
# 0  325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1  2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2  4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3  0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4  5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
#
#    album_total_tracks   album_type
# 0                  58  compilation
# 1                   1       single
# 2                  26        album
# 3                  16        album
# 4                  13        album

# %%
 nb = df.isnull().sum()
print(nb)
df [df.isnull().any (axis = 1)]
# Out:
# track_id              0
# track_name            2
# track_number          0
# track_popularity      0
# track_duration_ms     0
# explicit              0
# artist_name           4
# artist_popularity     4
# artist_followers      4
# artist_genres         4
# album_id              0
# album_name            2
# album_release_date    0
# album_total_tracks    0
# album_type            0
# dtype: int64
#                     track_id            track_name  track_number  \
# 436   3QhfFRPkhPCR1RMJWV1gde                 Radio             8
# 1396  2NbsBSshscKIPRG3kwBbfo   Never Felt So Alone             1
# 3618  37ns6v0HK4zMV1PpRLIsbx                   NaN             1
# 3885  5EhZC8GFOVXrpiUW22jncE        Urban Twilight             4
# 3886  0fM9dEhUFV4MHDuJgrcfOv  How You Get The Girl            10
# 4170  6N21iOdTYgYjDK1AyS0iUW                   NaN             2
#
#       track_popularity  track_duration_ms  explicit      artist_name  \
# 436                 65             214586      True              NaN
# 1396                68             160166     False              NaN
# 3618                 0                  0     False  Various Artists
# 3885                30             255634     False              NaN
# 3886                59             247533     False              NaN
# 4170                 0                  0      True  Various Artists
#
#       artist_popularity  artist_followers artist_genres  \
# 436                 NaN               NaN           NaN
# 1396                NaN               NaN           NaN
# 3618                0.0          2.78e+06            []
# 3885                NaN               NaN           NaN
# 3886                NaN               NaN           NaN
# 4170                0.0          2.78e+06            []
#
#                     album_id  \
# 436   0Dt3FbpMQwjoT5KNAw0IXR
# 1396  33JqWTchq6piiQddrRIvJX
# 3618  6ZANj7FHgq4Lozaq67DUaW
# 3885  1Cog6aZ6NwnJiuINc0LQEU
# 3886  1yGbNOtRIgdIiGHOEBaZWf
# 4170  49p6Te0TtN1Ew5qP5GIEQB
#
#                                             album_name album_release_date  \
# 436   Born To Die – Paradise Edition (Special Version)         2012-01-01
# 1396                               Never Felt So Alone         2023-04-07
# 3618                                               NaN               0000
# 3885                                         Darkbloom         2011-04-18
# 3886                                     1989 (Deluxe)         2014-01-01
# 4170                                               NaN               0000
#
#       album_total_tracks album_type
# 436                   24      album
# 1396                   1     single
# 3618                   1     single
# 3885                   5     single
# 3886                  19      album
# 4170                   2     single

# %%
#MATPLOTLIB

import matplotlib.pyplot as plt

#SEABORN

import seaborn as sns

# %%
sns.histplot(df['track_popularity'], bins=40)
plt.title("Distribution of track popularity")
# Out:
# Text(0.5, 1.0, 'Distribution of track popularity')

# %%
sns.scatterplot(x='artist_popularity', y='track_popularity', hue='track_duration_ms', data=df)
plt.title("track popularity en artist popularity, coloré par le track_duration_ms")
# Out:
# Text(0.5, 1.0, 'track_popularity vs artist_popularity, coloré par le track_duration_ms')

# %%
# Heatmap of correlation between numeric variables,
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
import plotly.express as px
# Use existing numeric and categorical columns
px.scatter(df, x='artist_popularity', y='artist_followers', color='track_popularity', title="artist followers vs artist_popularity Colored by track popularity")

# %%
# Importing the pyplot interface from Matplotlib
import matplotlib.pyplot as plt

# %%
year=[ 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
number_users=[ 4562, 2783, 7685, 2346, 9643, 8956, 7643, 3454, 4567,3456 , 2345, 12345]

# %%
plt.plot(year, number_users, color="green")
plt.xlabel("year")
plt.ylabel("number users")
plt.title("Evolution of number users")
plt.show()

# %%
# You can customize the line style, marker and color
plt.plot(year, number_users, linestyle='--', marker='v', color='r')
plt.xlabel("year")
plt.ylabel("number users")
plt.title("Evolution of number users")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(year, number_users, color="green")
plt.xlabel("year")
plt.ylabel("number users")
plt.title("Evolution of number users")
plt.show()

# %%
Year=[2015, 2017, 2019, 2021, 2023, 2025]
N_views=[1234, 2345, 8224,9345, 2765, 3456]
N_Followers=[567, 1234, 7089, 8456, 1235, 2000]

# %%
plt.figure(figsize=(8, 5))
plt.plot(Year, N_views, label="views")
plt.plot(Year, N_Followers, label="Followers")
plt.ylabel("N Views and Followers")
plt.legend()
plt.show()

# %%
# Point Clouds (scatter plot)
plt.figure(figsize=(5,4))
plt.scatter( N_views,N_Followers)
plt.xlabel('views')
plt.ylabel("followers")
plt.show()

# %%
import plotly

import plotly.graph_objects as go

import plotly.offline as pyo

from plotly.offline import init_notebook_mode

init_notebook_mode(connected=True)

fig = go.Figure(data=go.Scatter(x=year, y=number_users, mode='markers'))

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
